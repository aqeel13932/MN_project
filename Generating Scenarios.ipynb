# %%
from Scenarios import *
import numpy as np
import matplotlib.pyplot as plt

# %%
### Reverse 1 time step in 4th day with constant morning or night afterward
Generate_experiments(prefix="{}:(\"M20,N20,M20,N20,M20,",suffix=",N140\"),",counter=546,day=4,morning_night='M',extra="last 4 days constant night")
Generate_experiments(prefix="{}:(\"M20,N20,M20,N20,M20,",suffix=",N140\"),",counter=566,day=4,morning_night='N',extra="last 4 days constant night")
# Out:
# 547:("M20,N20,M20,N20,M20,N21,M19,N20,M20,N140"),
# 548:("M20,N20,M20,N20,M20,N20,M1,N1,M18,N20,M20,N140"),
# 549:("M20,N20,M20,N20,M20,N20,M2,N1,M17,N20,M20,N140"),
# 550:("M20,N20,M20,N20,M20,N20,M3,N1,M16,N20,M20,N140"),
# 551:("M20,N20,M20,N20,M20,N20,M4,N1,M15,N20,M20,N140"),
# 552:("M20,N20,M20,N20,M20,N20,M5,N1,M14,N20,M20,N140"),
# 553:("M20,N20,M20,N20,M20,N20,M6,N1,M13,N20,M20,N140"),
# 554:("M20,N20,M20,N20,M20,N20,M7,N1,M12,N20,M20,N140"),
# 555:("M20,N20,M20,N20,M20,N20,M8,N1,M11,N20,M20,N140"),
# 556:("M20,N20,M20,N20,M20,N20,M9,N1,M10,N20,M20,N140"),
# 557:("M20,N20,M20,N20,M20,N20,M10,N1,M9,N20,M20,N140"),
# 558:("M20,N20,M20,N20,M20,N20,M11,N1,M8,N20,M20,N140"),
# 559:("M20,N20,M20,N20,M20,N20,M12,N1,M7,N20,M20,N140"),
# 560:("M20,N20,M20,N20,M20,N20,M13,N1,M6,N20,M20,N140"),
# 561:("M20,N20,M20,N20,M20,N20,M14,N1,M5,N20,M20,N140"),
# 562:("M20,N20,M20,N20,M20,N20,M15,N1,M4,N20,M20,N140"),
# 563:("M20,N20,M20,N20,M20,N20,M16,N1,M3,N20,M20,N140"),
# ...

# %%
### Reverse 1 time step in a day
Generate_experiments(prefix="{}:(\"M20,N20,M20,",suffix=",N20,M20,N20,M20,N20,M20,N20,M20,N20\"),",counter=22,day=3,morning_night='M')
Generate_experiments(prefix="{}:(\"M20,N20,M20,",suffix=",N20,M20,N20,M20,N20,M20,N20,M20,N20\"),",counter=42,day=3,morning_night='N')
Generate_experiments(prefix="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,",suffix=",N20\"),",counter=62,day=7,morning_night='M')
Generate_experiments(prefix="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,",suffix=",N20\"),",counter=82,day=7,morning_night='N')

# %%
#3rd day morning expand (travel west)
m3expand_exp,m3expand_desc = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M{},N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N{}\"),",
    counter=104,day=3,increase=True,morning_night='M')
#3rd day morning short (travel east)
m3shorten_exp,m3shorten_desc  = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M{},N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M{}\"),",
    counter=124,day=3,increase=False,morning_night='M')
#3rd day night expand (travel west)
n3expand_exp,n3expand_desc =Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N{},M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N{}\"),",
    counter=144,day=3,increase=True,morning_night='N')
#3rd day night short (travel east)
n3shorten_exp,n3shorten_desc  = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N{},M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M{}\"),",
    counter=164,day=3,increase=False,morning_night='N')

print('\n'.join(map(str, m3expand_exp+m3shorten_exp+n3expand_exp+n3shorten_exp))) 
print('\n'.join(map(str, m3expand_desc+m3shorten_desc+n3expand_desc+n3shorten_desc)))
# Out:
# 105:("M20,N20,M20,N20,M21,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N19"),
# 106:("M20,N20,M20,N20,M22,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N18"),
# 107:("M20,N20,M20,N20,M23,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N17"),
# 108:("M20,N20,M20,N20,M24,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N16"),
# 109:("M20,N20,M20,N20,M25,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N15"),
# 110:("M20,N20,M20,N20,M26,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N14"),
# 111:("M20,N20,M20,N20,M27,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N13"),
# 112:("M20,N20,M20,N20,M28,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N12"),
# 113:("M20,N20,M20,N20,M29,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N11"),
# 114:("M20,N20,M20,N20,M30,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N10"),
# 115:("M20,N20,M20,N20,M31,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N9"),
# ...

# %%
#7th day morning expand (travel west)
m3expand_exp,m3expand_desc = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M{},N20,M20,N20,M20,N20,M20,N{}\"),",
    counter=184,day=7,increase=True,morning_night='M')
#7th day morning short (travel east)
m3shorten_exp,m3shorten_desc  = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M{},N20,M20,N20,M20,N20,M20,N20,M{}\"),",
    counter=204,day=7,increase=False,morning_night='M')
#7th day night expand (travel west)
n3expand_exp,n3expand_desc =Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N{},M20,N20,M20,N20,M20,N{}\"),",
    counter=224,day=7,increase=True,morning_night='N')
#7th day night short (travel east)
n3shorten_exp,n3shorten_desc  = Jetlag_exp_generator(
    base_experiment="{}:(\"M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N{},M20,N20,M20,N20,M20,N20,M{}\"),",
    counter=244,day=7,increase=False,morning_night='N')

print('\n'.join(map(str, m3expand_exp+m3shorten_exp+n3expand_exp+n3shorten_exp))) 
print('\n'.join(map(str, m3expand_desc+m3shorten_desc+n3expand_desc+n3shorten_desc)))
# Out:
# 185:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M21,N20,M20,N20,M20,N20,M20,N19"),
# 186:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M22,N20,M20,N20,M20,N20,M20,N18"),
# 187:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M23,N20,M20,N20,M20,N20,M20,N17"),
# 188:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M24,N20,M20,N20,M20,N20,M20,N16"),
# 189:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M25,N20,M20,N20,M20,N20,M20,N15"),
# 190:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M26,N20,M20,N20,M20,N20,M20,N14"),
# 191:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M27,N20,M20,N20,M20,N20,M20,N13"),
# 192:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M28,N20,M20,N20,M20,N20,M20,N12"),
# 193:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M29,N20,M20,N20,M20,N20,M20,N11"),
# 194:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M30,N20,M20,N20,M20,N20,M20,N10"),
# 195:("M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M20,N20,M31,N20,M20,N20,M20,N20,M20,N9"),
# ...

# %%
Constant_Cue_SinglePertrubation(counter=264,day=7,morning_night='M')
Constant_Cue_SinglePertrubation(counter=304,day=7,morning_night='N')
# Out:
# 265:("M240,N1,M79"),
# 266:("M241,N1,M78"),
# 267:("M242,N1,M77"),
# 268:("M243,N1,M76"),
# 269:("M244,N1,M75"),
# 270:("M245,N1,M74"),
# 271:("M246,N1,M73"),
# 272:("M247,N1,M72"),
# 273:("M248,N1,M71"),
# 274:("M249,N1,M70"),
# 275:("M250,N1,M69"),
# 276:("M251,N1,M68"),
# 277:("M252,N1,M67"),
# 278:("M253,N1,M66"),
# 279:("M254,N1,M65"),
# 280:("M255,N1,M64"),
# 281:("M256,N1,M63"),
# 282:("M257,N1,M62"),
# 283:("M258,N1,M61"),
# 284:("M259,N1,M60"),
# 285:("M260,N1,M59"),
# 286:("M261,N1,M58"),
# 287:("M262,N1,M57"),
# 288:("M263,N1,M56"),
# 289:("M264,N1,M55"),
# 290:("M265,N1,M54"),
# 291:("M266,N1,M53"),
# 292:("M267,N1,M52"),
# 293:("M268,N1,M51"),
# 294:("M269,N1,M50"),
# 295:("M270,N1,M49"),
# 296:("M271,N1,M48"),
# 297:("M272,N1,M47"),
# 298:("M273,N1,M46"),
# 299:("M274,N1,M45"),
# 300:("M275,N1,M44"),
# 301:("M276,N1,M43"),
# 302:("M277,N1,M42"),
# 303:("M278,N1,M41"),
# 304:("M279,N1,M40"),
# 265:"All constant M except day 7 step 1",
# ...

# %%
Constant_Cue_last4_SinglePertrubation(counter=466,day=5,morning_night='M')
# Out:
# 467:("M20,N20,M20,N20,M20,N20,M20,N20,M0,N1,M159"),
# 468:("M20,N20,M20,N20,M20,N20,M20,N20,M1,N1,M158"),
# 469:("M20,N20,M20,N20,M20,N20,M20,N20,M2,N1,M157"),
# 470:("M20,N20,M20,N20,M20,N20,M20,N20,M3,N1,M156"),
# 471:("M20,N20,M20,N20,M20,N20,M20,N20,M4,N1,M155"),
# 472:("M20,N20,M20,N20,M20,N20,M20,N20,M5,N1,M154"),
# 473:("M20,N20,M20,N20,M20,N20,M20,N20,M6,N1,M153"),
# 474:("M20,N20,M20,N20,M20,N20,M20,N20,M7,N1,M152"),
# 475:("M20,N20,M20,N20,M20,N20,M20,N20,M8,N1,M151"),
# 476:("M20,N20,M20,N20,M20,N20,M20,N20,M9,N1,M150"),
# 477:("M20,N20,M20,N20,M20,N20,M20,N20,M10,N1,M149"),
# 478:("M20,N20,M20,N20,M20,N20,M20,N20,M11,N1,M148"),
# 479:("M20,N20,M20,N20,M20,N20,M20,N20,M12,N1,M147"),
# 480:("M20,N20,M20,N20,M20,N20,M20,N20,M13,N1,M146"),
# 481:("M20,N20,M20,N20,M20,N20,M20,N20,M14,N1,M145"),
# 482:("M20,N20,M20,N20,M20,N20,M20,N20,M15,N1,M144"),
# 483:("M20,N20,M20,N20,M20,N20,M20,N20,M16,N1,M143"),
# 484:("M20,N20,M20,N20,M20,N20,M20,N20,M17,N1,M142"),
# ...

# %%
Constant_Cue_last4_SinglePertrubation(counter=426,day=5,morning_night='N')
# Out:
# 427:("M20,N20,M20,N20,M20,N20,M20,N20,N0,M1,N159"),
# 428:("M20,N20,M20,N20,M20,N20,M20,N20,N1,M1,N158"),
# 429:("M20,N20,M20,N20,M20,N20,M20,N20,N2,M1,N157"),
# 430:("M20,N20,M20,N20,M20,N20,M20,N20,N3,M1,N156"),
# 431:("M20,N20,M20,N20,M20,N20,M20,N20,N4,M1,N155"),
# 432:("M20,N20,M20,N20,M20,N20,M20,N20,N5,M1,N154"),
# 433:("M20,N20,M20,N20,M20,N20,M20,N20,N6,M1,N153"),
# 434:("M20,N20,M20,N20,M20,N20,M20,N20,N7,M1,N152"),
# 435:("M20,N20,M20,N20,M20,N20,M20,N20,N8,M1,N151"),
# 436:("M20,N20,M20,N20,M20,N20,M20,N20,N9,M1,N150"),
# 437:("M20,N20,M20,N20,M20,N20,M20,N20,N10,M1,N149"),
# 438:("M20,N20,M20,N20,M20,N20,M20,N20,N11,M1,N148"),
# 439:("M20,N20,M20,N20,M20,N20,M20,N20,N12,M1,N147"),
# 440:("M20,N20,M20,N20,M20,N20,M20,N20,N13,M1,N146"),
# 441:("M20,N20,M20,N20,M20,N20,M20,N20,N14,M1,N145"),
# 442:("M20,N20,M20,N20,M20,N20,M20,N20,N15,M1,N144"),
# 443:("M20,N20,M20,N20,M20,N20,M20,N20,N16,M1,N143"),
# 444:("M20,N20,M20,N20,M20,N20,M20,N20,N17,M1,N142"),
# ...

# %%
Constant_Cue_last4_SinglePertrubation(counter=344,day=7,morning_night='N')
Constant_Cue_last4_SinglePertrubation(counter=384,day=7,morning_night='M')
# Out:
# 345:("M20,N20,M20,N20,M20,N20,M20,N20,N80,M1,N79"),
# 346:("M20,N20,M20,N20,M20,N20,M20,N20,N81,M1,N78"),
# 347:("M20,N20,M20,N20,M20,N20,M20,N20,N82,M1,N77"),
# 348:("M20,N20,M20,N20,M20,N20,M20,N20,N83,M1,N76"),
# 349:("M20,N20,M20,N20,M20,N20,M20,N20,N84,M1,N75"),
# 350:("M20,N20,M20,N20,M20,N20,M20,N20,N85,M1,N74"),
# 351:("M20,N20,M20,N20,M20,N20,M20,N20,N86,M1,N73"),
# 352:("M20,N20,M20,N20,M20,N20,M20,N20,N87,M1,N72"),
# 353:("M20,N20,M20,N20,M20,N20,M20,N20,N88,M1,N71"),
# 354:("M20,N20,M20,N20,M20,N20,M20,N20,N89,M1,N70"),
# 355:("M20,N20,M20,N20,M20,N20,M20,N20,N90,M1,N69"),
# 356:("M20,N20,M20,N20,M20,N20,M20,N20,N91,M1,N68"),
# 357:("M20,N20,M20,N20,M20,N20,M20,N20,N92,M1,N67"),
# 358:("M20,N20,M20,N20,M20,N20,M20,N20,N93,M1,N66"),
# 359:("M20,N20,M20,N20,M20,N20,M20,N20,N94,M1,N65"),
# 360:("M20,N20,M20,N20,M20,N20,M20,N20,N95,M1,N64"),
# 361:("M20,N20,M20,N20,M20,N20,M20,N20,N96,M1,N63"),
# 362:("M20,N20,M20,N20,M20,N20,M20,N20,N97,M1,N62"),
# ...
